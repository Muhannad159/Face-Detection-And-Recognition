# %%
import cv2
image = cv2.imread("Dataset/Testing/s3/2.pgm")  # Replace "your_image.jpg" with the path to your image file

# Display the image
cv2.imshow("Image", image)

# Wait for a key press and then close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
